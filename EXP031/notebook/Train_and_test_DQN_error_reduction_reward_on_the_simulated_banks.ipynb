# %% [markdown]
# # EXP031: DQN with squared-error-reduction reward
#
# `Train_and_test_DQN_on_the_simulated_banks.ipynb`を基準に、回答前後の二乗推定誤差の減少量を報酬とします。
#
# $$r_{i,t}=\left(\hat{\theta}_{i,t-1}-\theta_{i,\mathrm{true}}\right)^2-\left(\hat{\theta}_{i,t}-\theta_{i,\mathrm{true}}\right)^2$$
#
# step 1の回答前推定値には各受検者の初期状態を使用します。真の能力値はシミュレーション中の報酬計算と評価にだけ使用し、DQNの状態には含めません。報酬とQ値は負にもなり得るため、Fisher情報量報酬版にあったネットワークパラメータの正値制約は適用しません。
#
# 評価結果では、従来どおり真値における累積Fisher情報量を`CumReward`、学習目的である二乗誤差減少量の累積値を`CumTaskReward`として別々に保存します。

# %%
try:
    from google.colab import drive
except ModuleNotFoundError:
    print("Local environment detected; Google Drive mount skipped.")
else:
    drive.mount("/content/drive")
# Out:
# Local environment detected; Google Drive mount skipped.

# %%
# -*- coding: utf-8 -*-
import copy
from dataclasses import dataclass
from pathlib import Path
from typing import Any, Tuple, cast

import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from scipy.optimize import minimize_scalar

if torch.cuda.is_available():
    device = torch.device("cuda")
elif torch.backends.mps.is_available():
    device = torch.device("mps")
else:
    device = torch.device("cpu")


def find_project_root():
    candidates = []
    if "__file__" in globals():
        script_dir = Path(__file__).resolve().parent
        candidates.extend([script_dir, *script_dir.parents])

    cwd = Path.cwd().resolve()
    candidates.extend(
        [
            cwd,
            *cwd.parents,
            cwd / "Grad_Research",
            cwd
            / "Adaptive-Testing-Based-on-Reinforcement-Learning-Considering-Response-History",
            Path("/content/Grad_Research"),
            Path(
                "/content/Adaptive-Testing-Based-on-Reinforcement-Learning-Considering-Response-History"
            ),
            Path("/content/drive/MyDrive/Grad_Research"),
            Path(
                "/content/drive/MyDrive/Adaptive-Testing-Based-on-Reinforcement-Learning-Considering-Response-History"
            ),
            Path("/content/drive/MyDrive/Colab Notebooks/Grad_Research"),
            Path(
                "/content/drive/MyDrive/Colab Notebooks/Adaptive-Testing-Based-on-Reinforcement-Learning-Considering-Response-History"
            ),
        ]
    )

    for root in candidates:
        if (root / "data").is_dir():
            return root

    try:
        from google.colab import drive

        drive.mount("/content/drive")
    except Exception:
        pass

    for root in candidates:
        if (root / "data").is_dir():
            return root

    raise FileNotFoundError(
        "Could not find the project root. "
        "In Colab, place the repository at MyDrive/Grad_Research or /content/Grad_Research."
    )


ROOT = find_project_root()
EXP031_DIR = ROOT / "EXP031"
MODEL_DIR = EXP031_DIR / "models"
RESULTS_DIR = EXP031_DIR / "results"

print(f"Device      : {device}")
print(f"Project root: {ROOT}")
print(f"Model dir   : {MODEL_DIR}")
print(f"Results dir : {RESULTS_DIR}")
# Out:
# Device      : mps
# Project root: /Users/itsuki/Adaptive-Testing-Based-on-Reinforcement-Learning-Considering-Response-History
# Model dir   : /Users/itsuki/Adaptive-Testing-Based-on-Reinforcement-Learning-Considering-Response-History/EXP031/models
# Results dir : /Users/itsuki/Adaptive-Testing-Based-on-Reinforcement-Learning-Considering-Response-History/EXP031/results

# %%
@dataclass
class Config:
    # Network
    input_size: int = 1  # state = [theta_hat]
    first_hidden: int = 50
    second_hidden: int = 30
    dropout_rate: float = 0.0

    # Training
    test_length: int = 40
    gamma: float = 0.1
    memory_capacity: int = 1000
    epsilon: float = 0.1
    batch_size: int = 128
    q_network_iteration: int = 40
    learning_rate: float = 1e-3
    training_size: int = 1000
    validation_size: int = 200
    validation_interval: int = 50

    # Ability estimation: 'MLE' | 'EAP'
    estimation_method: str = "EAP"

    # EAP quadrature (used only when estimation_method='EAP')
    n_quad: int = 62
    prior_low: float = -4.0
    prior_high: float = 4.0

    # Bank / training theta distribution
    bank_type: str = "uncor"  # 'uncor' | 'cor'
    bank_id: int = 1
    prior: str = "normal"  # training theta: 'normal' | 'uniform'
    n_items: int = 500

    # Evaluation reproducibility (aligned with the MFI notebook)
    seed: int = 20260430

# %%
def RESPOND(item_para, theta, D=1):
    a = item_para[:, 0]
    b = item_para[:, 1]
    c = item_para[:, 2]
    p = (1 - c) / (1 + np.exp(-D * a * (theta - b))) + c
    return (np.random.random(size=p.shape) <= p).astype(int)


def FI(item_para, theta, D=1):
    a = item_para[:, 0]
    b = item_para[:, 1]
    c = item_para[:, 2]
    return (
        D**2
        * a**2
        * (1 - c)
        / (c + np.exp(D * a * (theta - b)))
        / (1 + np.exp(-D * a * (theta - b))) ** 2
    )


def squared_error_reduction_reward(theta_previous, theta_hat, theta_true):
    theta_true = np.asarray(theta_true)
    previous_error = np.square(np.asarray(theta_previous) - theta_true)
    current_error = np.square(np.asarray(theta_hat) - theta_true)
    return previous_error - current_error


def MLE(item_paras, resp, D=1):
    a = item_paras[:, 0]
    b = item_paras[:, 1]
    c = item_paras[:, 2]

    def mins_likelihood(x):
        logl = 0
        for i in range(len(resp)):
            p = (1 - c[i]) / (1 + np.exp(-D * a[i] * (x - b[i]))) + c[i]
            p = np.clip(p, 1e-10, 1 - 1e-10)
            logl -= resp[i] * np.log(p) + (1 - resp[i]) * np.log(1 - p)
        return logl

    result = cast(
        Any, minimize_scalar(mins_likelihood, bounds=(-4, 4), method="bounded")
    )
    return np.array(result.x).reshape(1)


def MLE_TEST(item_paras, resp, D=1):
    def mins_likelihood(x):
        logl = 0
        for i in range(resp_i.shape[0]):
            p = (1 - c[i]) / (1 + np.exp(-D * a[i] * (x - b[i]))) + c[i]
            p = np.clip(p, 1e-10, 1 - 1e-10)
            logl -= resp_i[i] * np.log(p) + (1 - resp_i[i]) * np.log(1 - p)
        return logl

    theta = np.zeros(resp.shape[1])
    for i in range(resp.shape[1]):
        resp_i = resp[:, i]
        a = item_paras[:, i, 0]
        b = item_paras[:, i, 1]
        c = item_paras[:, i, 2]
        result = cast(
            Any, minimize_scalar(mins_likelihood, bounds=(-4, 4), method="bounded")
        )
        theta[i] = result.x
    return np.expand_dims(theta, axis=0)


def EAP_quadrature(
    item_paras: np.ndarray,
    resp: np.ndarray,
    n_quad: int = 62,
    prior_low: float = -4.0,
    prior_high: float = 4.0,
    D: float = 1.0,
) -> Tuple[float, float]:
    theta_grid = np.linspace(prior_low, prior_high, n_quad)
    log_prior = np.zeros(n_quad)

    a = item_paras[:, 0]
    b = item_paras[:, 1]
    c = item_paras[:, 2]
    p = c[:, None] + (1 - c[:, None]) / (
        1 + np.exp(-D * a[:, None] * (theta_grid[None, :] - b[:, None]))
    )
    p = np.clip(p, 1e-10, 1 - 1e-10)
    log_lik = np.sum(
        resp[:, None] * np.log(p) + (1 - resp[:, None]) * np.log(1 - p),
        axis=0,
    )

    log_post = log_lik + log_prior
    log_post -= log_post.max()
    post = np.exp(log_post)
    post /= post.sum()

    eap_mean = float(np.sum(theta_grid * post))
    eap_var = float(np.sum((theta_grid - eap_mean) ** 2 * post))
    return eap_mean, eap_var


def get_estimation_method(cfg):
    method = cfg.estimation_method.upper()
    if method not in {"MLE", "EAP"}:
        raise ValueError(
            f"Unsupported estimation_method: {cfg.estimation_method!r}. "
            "Use 'MLE' or 'EAP'."
        )
    return method


def estimate_theta_single(cfg, administered_items, responses, current_theta):
    method = get_estimation_method(cfg)
    if method == "EAP":
        theta_hat, _ = EAP_quadrature(
            administered_items,
            responses,
            n_quad=cfg.n_quad,
            prior_low=cfg.prior_low,
            prior_high=cfg.prior_high,
        )
        return theta_hat

    if len(np.unique(responses)) == 1:
        if responses[-1] == 1:
            return current_theta + (item_bank[:, 1].max() - current_theta) / 2
        return current_theta - (current_theta - item_bank[:, 1].min()) / 2
    return float(MLE(administered_items, responses)[0])


def estimate_theta_batch(cfg, item_ids, responses, current_theta):
    method = get_estimation_method(cfg)
    testing_size = responses.shape[1]
    theta_hat = np.zeros(testing_size)

    if method == "EAP":
        for subject in range(testing_size):
            theta_hat[subject], _ = EAP_quadrature(
                item_bank[item_ids[:, subject]],
                responses[:, subject],
                n_quad=cfg.n_quad,
                prior_low=cfg.prior_low,
                prior_high=cfg.prior_high,
            )
        return theta_hat

    idx_full = np.sum(responses, axis=0) == responses.shape[0]
    idx_zero = np.sum(responses, axis=0) == 0
    idx_norm = ~(idx_full | idx_zero)
    theta_hat[idx_full] = (
        current_theta[idx_full] + (item_bank[:, 1].max() - current_theta[idx_full]) / 2
    )
    theta_hat[idx_zero] = (
        current_theta[idx_zero] - (current_theta[idx_zero] - item_bank[:, 1].min()) / 2
    )
    if np.any(idx_norm):
        theta_hat[idx_norm] = np.squeeze(
            MLE_TEST(
                item_bank[item_ids[:, idx_norm]],
                responses[:, idx_norm],
            )
        )
    return theta_hat


def estimation_label(cfg):
    return "EAP_unif" if get_estimation_method(cfg) == "EAP" else "MLE"

# %%
class Net(nn.Module):
    def __init__(
        self, input_size, first_hidden, second_hidden, action_space, dropout_rate
    ):
        super().__init__()
        self.fc1 = nn.Linear(input_size, first_hidden)
        self.fc2 = nn.Linear(first_hidden, second_hidden)
        self.out = nn.Linear(second_hidden, action_space)
        self.dropout = nn.Dropout(dropout_rate)

    def forward(self, x):
        x = self.dropout(self.fc1(x))
        x = F.relu(x)
        x = self.dropout(self.fc2(x))
        x = F.relu(x)
        return self.out(x)

    def initialize(self):
        for module in self.modules():
            if isinstance(module, nn.Linear):
                nn.init.kaiming_normal_(module.weight)


def Choose_Action(item_id, state, epsilon):
    if np.random.rand() >= epsilon:
        state_t = torch.unsqueeze(torch.FloatTensor(state), 0).to(device)
        item_id_t = torch.from_numpy(item_id).to(device).long()
        action_value = eval_net(state_t)
        action_value[:, item_id_t] = -torch.inf
        action = torch.max(action_value, -1)[1].cpu().numpy()
    else:
        if any(item_id):
            action = (
                np.random.choice(np.delete(np.arange(action_space), item_id))
                .astype("int64")
                .reshape(1)
            )
        else:
            action = (
                np.random.choice(np.arange(action_space)).astype("int64").reshape(1)
            )
    return action


def Choose_Action_Test(item_id, state):
    state_t = torch.FloatTensor(state.swapaxes(0, 1)).to(device)
    action_value = eval_net(state_t).detach().cpu().numpy()
    if item_id.shape[0] > 0:
        action_value[
            np.tile(
                np.arange(item_id.shape[1])[np.newaxis, :],
                (item_id.shape[0], 1),
            ),
            item_id,
        ] = -np.inf
    return action_value.argmax(axis=1)

# %%
def TRAIN(cfg):
    get_estimation_method(cfg)
    best_valid = None
    best_state = None

    loss_func = nn.MSELoss()
    eval_net.train()
    optimizer = optim.Adam(eval_net.parameters(), lr=cfg.learning_rate)

    # memory layout:
    # [state, action, reward, next_state, terminal, next_available(action_space)]
    memory_width = cfg.input_size * 2 + 3 + action_space
    memory = np.zeros((cfg.memory_capacity, memory_width))
    memory_counter = 0
    learn_step_counter = 0
    training_losses_since_validation = []
    loss_history_rows = []

    if cfg.prior == "normal":
        training_theta = np.random.randn(cfg.training_size)
    elif cfg.prior == "uniform":
        training_theta = np.random.uniform(-3, 3, cfg.training_size)
    else:
        raise ValueError(f"Unsupported prior: {cfg.prior!r}.")

    for j in range(cfg.training_size):
        state = np.array([np.random.rand() - 0.5])
        item_id = np.array([]).astype("int64")
        resp = np.array([]).astype("int64")

        for i in range(cfg.test_length):
            action = Choose_Action(item_id, state, cfg.epsilon)
            item_id = np.concatenate((item_id, action))
            resp = np.concatenate((resp, RESPOND(item_bank[action], training_theta[j])))

            theta_hat = estimate_theta_single(cfg, item_bank[item_id], resp, state[-1])
            reward = np.atleast_1d(
                squared_error_reduction_reward(state[-1], theta_hat, training_theta[j])
            )
            next_state = np.array([theta_hat])

            terminal = float(i == cfg.test_length - 1)
            next_available = np.ones(action_space, dtype=np.float32)
            next_available[item_id] = 0.0

            memory[memory_counter % cfg.memory_capacity, :] = np.hstack(
                (state, action, reward, next_state, terminal, next_available)
            )
            memory_counter += 1
            state = next_state

            if memory_counter >= cfg.batch_size:
                batch_memory = memory[
                    np.random.choice(
                        min(memory_counter, cfg.memory_capacity), cfg.batch_size
                    ),
                    :,
                ]
                next_state_start = cfg.input_size + 2
                next_state_end = next_state_start + cfg.input_size
                terminal_col = next_state_end
                next_available_start = terminal_col + 1

                batch_state = torch.FloatTensor(batch_memory[:, : cfg.input_size]).to(
                    device
                )
                batch_action = torch.LongTensor(
                    batch_memory[:, cfg.input_size : cfg.input_size + 1].astype(int)
                ).to(device)
                batch_reward = torch.FloatTensor(
                    batch_memory[:, cfg.input_size + 1 : cfg.input_size + 2]
                ).to(device)
                batch_next_state = torch.FloatTensor(
                    batch_memory[:, next_state_start:next_state_end]
                ).to(device)
                batch_terminal = torch.FloatTensor(
                    batch_memory[:, terminal_col : terminal_col + 1]
                ).to(device)
                batch_next_available = torch.BoolTensor(
                    batch_memory[:, next_available_start:].astype(bool)
                ).to(device)

                q_eval = eval_net(batch_state).gather(1, batch_action)
                q_next = target_net(batch_next_state).detach()
                q_next = q_next.masked_fill(~batch_next_available, -torch.inf)
                q_next_max = q_next.max(1)[0].view(cfg.batch_size, 1)
                q_next_max = q_next_max.masked_fill(batch_terminal.bool(), 0.0)
                q_target = batch_reward + cfg.gamma * q_next_max
                loss = loss_func(q_eval, q_target)

                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
                training_losses_since_validation.append(loss.item())

                learn_step_counter += 1
                if learn_step_counter % cfg.q_network_iteration == 0:
                    target_net.load_state_dict(eval_net.state_dict())

        # Validation
        if (j + 1) % cfg.validation_interval == 0:
            eval_net.eval()
            mean_training_loss = (
                float(np.mean(training_losses_since_validation))
                if training_losses_since_validation
                else np.nan
            )
            valid_loss_sum = 0.0
            valid_transition_count = 0
            valid_theta = np.random.choice(training_theta, cfg.validation_size)
            valid_bias = np.zeros((cfg.test_length, cfg.validation_size))
            valid_cum_task_reward = np.zeros(cfg.validation_size)
            valid_cum_fisher_information = np.zeros(cfg.validation_size)

            state = np.expand_dims(np.random.rand(cfg.validation_size) - 0.5, axis=0)
            item_id = np.array([])

            with torch.no_grad():
                for i in range(cfg.test_length):
                    action = Choose_Action_Test(item_id, state)
                    valid_cum_fisher_information += FI(item_bank[action], valid_theta)
                    if i == 0:
                        item_id = action[np.newaxis, :]
                        resp = RESPOND(item_bank[action], valid_theta)[np.newaxis, :]
                    else:
                        item_id = np.concatenate((item_id, action[np.newaxis, :]))
                        resp = np.concatenate(
                            (
                                resp,
                                RESPOND(item_bank[action], valid_theta)[np.newaxis, :],
                            )
                        )

                    theta_0 = estimate_theta_batch(cfg, item_id, resp, state[-1])
                    reward = squared_error_reduction_reward(
                        state[-1], theta_0, valid_theta
                    )[:, np.newaxis]
                    valid_cum_task_reward += reward[:, 0]
                    next_state = theta_0[np.newaxis, :]

                    state_tensor = torch.FloatTensor(state.T).to(device)
                    action_tensor = torch.LongTensor(action[:, np.newaxis]).to(device)
                    reward_tensor = torch.FloatTensor(reward).to(device)
                    next_state_tensor = torch.FloatTensor(next_state.T).to(device)
                    q_eval = eval_net(state_tensor).gather(1, action_tensor)
                    q_next = target_net(next_state_tensor)

                    next_available = np.ones(
                        (cfg.validation_size, action_space), dtype=bool
                    )
                    next_available[
                        np.arange(cfg.validation_size)[:, np.newaxis],
                        item_id.T,
                    ] = False
                    next_available_tensor = torch.BoolTensor(next_available).to(device)
                    q_next = q_next.masked_fill(~next_available_tensor, -torch.inf)
                    q_next_max = q_next.max(1)[0].view(cfg.validation_size, 1)
                    if i == cfg.test_length - 1:
                        q_next_max = torch.zeros_like(q_next_max)
                    q_target = reward_tensor + cfg.gamma * q_next_max
                    valid_loss_sum += F.mse_loss(
                        q_eval, q_target, reduction="sum"
                    ).item()
                    valid_transition_count += cfg.validation_size

                    state = next_state
                    valid_bias[i] = theta_0 - valid_theta

            mean_validation_loss = valid_loss_sum / valid_transition_count
            mean_cum_task_reward = float(np.mean(valid_cum_task_reward))
            mean_cum_fisher_information = float(np.mean(valid_cum_fisher_information))
            step_valid = np.transpose(
                np.vstack(
                    (
                        np.arange(1, cfg.test_length + 1),
                        np.mean(valid_bias, axis=1),
                        np.sqrt(np.mean(valid_bias**2, axis=1)),
                        np.mean(abs(valid_bias), axis=1),
                    )
                )
            )

            print(
                f"subject: {j + 1}, "
                f"training loss: {mean_training_loss:.6f}, "
                f"validation loss: {mean_validation_loss:.6f}, "
                f"mean cumulative task reward: {mean_cum_task_reward:.6f}, "
                f"mean cumulative FI: {mean_cum_fisher_information:.6f}"
            )
            loss_history_rows.append(
                {
                    "training_examinees": j + 1,
                    "mean_training_td_loss": mean_training_loss,
                    "mean_validation_td_loss": mean_validation_loss,
                    "mean_validation_cumulative_task_reward": (mean_cum_task_reward),
                    "mean_validation_cumulative_fisher_information": (
                        mean_cum_fisher_information
                    ),
                }
            )

            result_valid = np.mean(step_valid[6:, 1:], axis=0)
            if best_valid is None:
                best_valid = result_valid
                best_state = copy.deepcopy(eval_net.state_dict())
            elif result_valid[1] < best_valid[1]:
                best_valid = result_valid
                best_state = copy.deepcopy(eval_net.state_dict())

            training_losses_since_validation.clear()
            eval_net.train()

    return best_state, pd.DataFrame(loss_history_rows)

# %%
def TEST(cfg, theta_test):
    get_estimation_method(cfg)
    np.random.seed(cfg.seed)

    with torch.no_grad():
        eval_net.eval()
        testing_size = len(theta_test)

        state = np.expand_dims(np.random.rand(testing_size) - 0.5, axis=0)
        item_id = np.array([])
        dqn_step = np.zeros((1, 6))
        cum_fisher_information = np.zeros(testing_size)
        cum_task_reward = np.zeros(testing_size)
        cum_fisher_history = np.empty((0, testing_size))
        cum_task_reward_history = np.empty((0, testing_size))

        for i in range(cfg.test_length):
            action = Choose_Action_Test(item_id, state)
            cum_fisher_information += FI(item_bank[action], theta_test)
            if i == 0:
                item_id = action[np.newaxis, :]
                resp = RESPOND(item_bank[action], theta_test)[np.newaxis, :]
            else:
                item_id = np.concatenate((item_id, action[np.newaxis, :]))
                resp = np.concatenate(
                    (resp, RESPOND(item_bank[action], theta_test)[np.newaxis, :])
                )

            theta_0 = estimate_theta_batch(cfg, item_id, resp, state[-1])
            task_reward = squared_error_reduction_reward(state[-1], theta_0, theta_test)
            cum_task_reward += task_reward
            cum_fisher_history = np.concatenate(
                (
                    cum_fisher_history,
                    cum_fisher_information[np.newaxis, :],
                )
            )
            cum_task_reward_history = np.concatenate(
                (cum_task_reward_history, cum_task_reward[np.newaxis, :])
            )

            if i == 0:
                theta = theta_0[np.newaxis, :]
            else:
                theta = np.concatenate((theta, theta_0[np.newaxis, :]))

            dqn_step = np.vstack(
                [
                    dqn_step,
                    np.array(
                        [
                            i + 1,
                            np.mean(theta_0 - theta_test),
                            np.sqrt(np.mean((theta_0 - theta_test) ** 2)),
                            np.mean(abs(theta_0 - theta_test)),
                            np.mean(cum_fisher_information),
                            np.mean(cum_task_reward),
                        ]
                    ),
                ]
            )
            print(
                "step {:g}, bias {:.3f}, rmse {:.3f}, mae {:.3f}, "
                "cum_reward {:.3f}, cum_task_reward {:.3f}".format(*dqn_step[-1])
            )

            state = theta_0[np.newaxis, :]

        user_id_col = np.repeat(np.arange(1, testing_size + 1), cfg.test_length)
        step_col = np.tile(np.arange(1, cfg.test_length + 1), testing_size)
        dqn_data = pd.DataFrame(
            {
                "userID": user_id_col,
                "step": step_col,
                "itemID": (item_id + 1).T.reshape(-1),
                "resp": resp.T.reshape(-1),
                "theta_true": np.repeat(theta_test, cfg.test_length),
                "theta_est": theta.T.reshape(-1),
                "bias": (theta - theta_test).T.reshape(-1),
                "cum_reward": cum_fisher_history.T.reshape(-1),
                "cum_task_reward": cum_task_reward_history.T.reshape(-1),
            }
        )
        dqn_summary = pd.DataFrame(
            dqn_step[1:],
            columns=[
                "step",
                "Bias",
                "RMSE",
                "MAE",
                "CumReward",
                "CumTaskReward",
            ],
        )

        RESULTS_DIR.mkdir(parents=True, exist_ok=True)
        stem = (
            f"{cfg.bank_type}_{cfg.bank_id}_DQN_{estimation_label(cfg)}"
            f"_error_reduction_reward_gamma_{cfg.gamma}"
        )
        records_path = RESULTS_DIR / f"records_{stem}.csv"
        summary_path = RESULTS_DIR / f"summary_{stem}.csv"
        dqn_data.to_csv(records_path, index=False)
        dqn_summary.to_csv(summary_path, index=False)
        print(f"\nSaved records to: {records_path}")
        print(f"Saved summary to: {summary_path}")

        return dqn_data, dqn_summary

# %%
cfg = Config(
    # Network
    input_size=1,
    first_hidden=50,
    second_hidden=30,
    dropout_rate=0.0,
    # Training
    test_length=40,
    gamma=0.1,
    memory_capacity=1000,
    epsilon=0.1,
    batch_size=128,
    q_network_iteration=40,
    learning_rate=1e-3,
    training_size=1000,
    validation_size=200,
    validation_interval=50,
    # Ability estimation
    estimation_method="MLE",
    n_quad=62,
    prior_low=-4.0,
    prior_high=4.0,
    # Bank / theta
    bank_type="uncor",
    bank_id=1,
    prior="normal",
    n_items=500,
    seed=20260430,
)

bank_dir = {
    "uncor": ROOT / "data" / "uncorrelated_banks",
    "cor": ROOT / "data" / "correlated_banks",
}[cfg.bank_type]

item_bank = np.array(
    pd.read_csv(bank_dir / f"item_bank_{cfg.bank_type}_{cfg.bank_id}.csv")[
        ["a", "b", "c"]
    ]
)[: cfg.n_items]
action_space = item_bank.shape[0]

theta_test = np.array(
    pd.read_csv(ROOT / "data" / "theta_true" / f"theta_true_{cfg.bank_id}.csv")["x"]
)

print(f"item bank  : {item_bank.shape}")
print(f"theta_test : {theta_test.shape}")
print(f"\nConfig:\n{cfg}")
# Out:
# item bank  : (500, 3)
# theta_test : (5000,)
#
# Config:
# Config(input_size=1, first_hidden=50, second_hidden=30, dropout_rate=0.0, test_length=40, gamma=0.1, memory_capacity=1000, epsilon=0.1, batch_size=128, q_network_iteration=40, learning_rate=0.001, training_size=1000, validation_size=200, validation_interval=50, estimation_method='MLE', n_quad=62, prior_low=-4.0, prior_high=4.0, bank_type='uncor', bank_id=1, prior='normal', n_items=500, seed=20260430)

# %%
eval_net = Net(
    cfg.input_size,
    cfg.first_hidden,
    cfg.second_hidden,
    action_space,
    cfg.dropout_rate,
).to(device)
target_net = Net(
    cfg.input_size,
    cfg.first_hidden,
    cfg.second_hidden,
    action_space,
    cfg.dropout_rate,
).to(device)
eval_net.initialize()
target_net.initialize()

best_state, loss_history = TRAIN(cfg)

assert best_state is not None, (
    "No checkpoint was saved. Increase training_size or lower validation_interval."
)
eval_net.load_state_dict(best_state)

MODEL_DIR.mkdir(parents=True, exist_ok=True)
model_path = MODEL_DIR / (
    f"dqn_{estimation_label(cfg)}_{cfg.bank_type}_{cfg.bank_id}"
    f"_error_reduction_reward_gamma_{cfg.gamma}.pt"
)
torch.save(eval_net.state_dict(), model_path)
print(f"Model saved to: {model_path}")

loss_history_path = RESULTS_DIR / (
    f"loss_history_{cfg.bank_type}_{cfg.bank_id}_DQN_"
    f"{estimation_label(cfg)}_error_reduction_reward_gamma_{cfg.gamma}.csv"
)
RESULTS_DIR.mkdir(parents=True, exist_ok=True)
loss_history.to_csv(loss_history_path, index=False)
print(f"Loss history saved to: {loss_history_path}")

records, summary = TEST(cfg, theta_test)
# Out:
# subject: 50, training loss: 1.331165, validation loss: 1.054138, mean cumulative task reward: 0.853142, mean cumulative FI: 6.032307
# subject: 100, training loss: 0.589030, validation loss: 0.911131, mean cumulative task reward: 0.764172, mean cumulative FI: 5.688420
# subject: 150, training loss: 0.627167, validation loss: 1.412402, mean cumulative task reward: 0.906385, mean cumulative FI: 5.629815
# subject: 200, training loss: 0.528705, validation loss: 1.166170, mean cumulative task reward: 0.972603, mean cumulative FI: 5.676469
# subject: 250, training loss: 0.897633, validation loss: 1.665115, mean cumulative task reward: 1.030943, mean cumulative FI: 5.157967
# subject: 300, training loss: 0.550976, validation loss: 1.981884, mean cumulative task reward: 0.824201, mean cumulative FI: 5.269796
# subject: 350, training loss: 0.761947, validation loss: 1.261268, mean cumulative task reward: 0.743953, mean cumulative FI: 5.633212
# subject: 400, training loss: 0.799607, validation loss: 1.061569, mean cumulative task reward: 0.890940, mean cumulative FI: 5.489024
# subject: 450, training loss: 0.928229, validation loss: 1.374711, mean cumulative task reward: 0.650677, mean cumulative FI: 5.616463
# subject: 500, training loss: 0.652656, validation loss: 1.462098, mean cumulative task reward: 0.948552, mean cumulative FI: 5.523727
# subject: 550, training loss: 0.651514, validation loss: 1.727825, mean cumulative task reward: 0.736488, mean cumulative FI: 5.105162
# subject: 600, training loss: 0.788596, validation loss: 1.122925, mean cumulative task reward: 0.744324, mean cumulative FI: 5.545369
# subject: 650, training loss: 1.102910, validation loss: 1.265393, mean cumulative task reward: 0.860146, mean cumulative FI: 5.497159
# subject: 700, training loss: 0.673166, validation loss: 0.808756, mean cumulative task reward: 0.877539, mean cumulative FI: 6.241201
# subject: 750, training loss: 0.515382, validation loss: 1.062672, mean cumulative task reward: 0.722162, mean cumulative FI: 5.629192
# subject: 800, training loss: 0.857185, validation loss: 1.467289, mean cumulative task reward: 0.907827, mean cumulative FI: 5.540241
# subject: 850, training loss: 1.147073, validation loss: 1.290723, mean cumulative task reward: 0.788419, mean cumulative FI: 5.183949
# subject: 900, training loss: 1.148450, validation loss: 0.946224, mean cumulative task reward: 0.741762, mean cumulative FI: 5.612747
# subject: 950, training loss: 0.610361, validation loss: 1.121443, mean cumulative task reward: 0.773994, mean cumulative FI: 5.394535
# subject: 1000, training loss: 0.661963, validation loss: 0.766049, mean cumulative task reward: 0.983433, mean cumulative FI: 5.239000
# Model saved to: /Users/itsuki/Adaptive-Testing-Based-on-Reinforcement-Learning-Considering-Response-History/EXP031/models/dqn_MLE_uncor_1_error_reduction_reward_gamma_0.1.pt
# Loss history saved to: /Users/itsuki/Adaptive-Testing-Based-on-Reinforcement-Learning-Considering-Response-History/EXP031/results/loss_history_uncor_1_DQN_MLE_error_reduction_reward_gamma_0.1.csv
# step 1, bias 0.430, rmse 1.364, mae 1.135, cum_reward 0.240, cum_task_reward -0.790
# step 2, bias 0.735, rmse 1.713, mae 1.460, cum_reward 0.346, cum_task_reward -1.862
# step 3, bias 0.289, rmse 1.315, mae 1.051, cum_reward 0.513, cum_task_reward -0.658
# step 4, bias 0.173, rmse 1.159, mae 0.916, cum_reward 0.696, cum_task_reward -0.271
# step 5, bias 0.125, rmse 1.084, mae 0.852, cum_reward 0.859, cum_task_reward -0.103
# step 6, bias 0.064, rmse 0.992, mae 0.778, cum_reward 1.053, cum_task_reward 0.089
# step 7, bias 0.049, rmse 0.931, mae 0.731, cum_reward 1.220, cum_task_reward 0.206
# step 8, bias 0.029, rmse 0.878, mae 0.692, cum_reward 1.369, cum_task_reward 0.301
# step 9, bias 0.017, rmse 0.835, mae 0.656, cum_reward 1.529, cum_task_reward 0.375
# step 10, bias 0.004, rmse 0.799, mae 0.625, cum_reward 1.696, cum_task_reward 0.434
# step 11, bias 0.003, rmse 0.763, mae 0.596, cum_reward 1.860, cum_task_reward 0.490
# step 12, bias -0.005, rmse 0.744, mae 0.579, cum_reward 2.011, cum_task_reward 0.519
# step 13, bias -0.003, rmse 0.721, mae 0.561, cum_reward 2.157, cum_task_reward 0.553
# step 14, bias -0.005, rmse 0.702, mae 0.547, cum_reward 2.290, cum_task_reward 0.579
# step 15, bias -0.008, rmse 0.685, mae 0.532, cum_reward 2.420, cum_task_reward 0.603
# step 16, bias -0.007, rmse 0.668, mae 0.518, cum_reward 2.547, cum_task_reward 0.626
# step 17, bias -0.013, rmse 0.657, mae 0.509, cum_reward 2.673, cum_task_reward 0.641
# step 18, bias -0.014, rmse 0.642, mae 0.498, cum_reward 2.803, cum_task_reward 0.660
# step 19, bias -0.018, rmse 0.633, mae 0.490, cum_reward 2.933, cum_task_reward 0.672
# subject: 450, training loss: 0.871937, validation loss: 1.499810, mean cumulative task reward: 0.818084, mean cumulative FI: 5.558601
# subject: 500, training loss: 0.643594, validation loss: 1.194062, mean cumulative task reward: 0.706939, mean cumulative FI: 5.466269
# subject: 550, training loss: 0.629793, validation loss: 0.983026, mean cumulative task reward: 0.831534, mean cumulative FI: 5.290056
# subject: 600, training loss: 0.472745, validation loss: 1.103512, mean cumulative task reward: 0.868513, mean cumulative FI: 5.421831
# subject: 650, training loss: 0.575906, validation loss: 1.166944, mean cumulative task reward: 0.884804, mean cumulative FI: 5.369214
# subject: 700, training loss: 0.606202, validation loss: 1.618193, mean cumulative task reward: 0.748856, mean cumulative FI: 5.841740
# subject: 750, training loss: 0.770201, validation loss: 1.347954, mean cumulative task reward: 0.779625, mean cumulative FI: 6.054245
# subject: 800, training loss: 0.677644, validation loss: 0.951285, mean cumulative task reward: 0.728542, mean cumulative FI: 6.235953
# subject: 850, training loss: 0.460196, validation loss: 1.452905, mean cumulative task reward: 0.834564, mean cumulative FI: 5.359204
# subject: 900, training loss: 0.433118, validation loss: 1.144541, mean cumulative task reward: 0.870281, mean cumulative FI: 5.508085
# subject: 950, training loss: 0.727903, validation loss: 1.500690, mean cumulative task reward: 0.933806, mean cumulative FI: 5.610685
# subject: 1000, training loss: 0.597037, validation loss: 1.003156, mean cumulative task reward: 0.883864, mean cumulative FI: 5.227861
# Model saved to: /Users/itsuki/Adaptive-Testing-Based-on-Reinforcement-Learning-Considering-Response-History/EXP031/models/dqn_MLE_uncor_1_error_reduction_reward_gamma_0.3.pt
# Loss history saved to: /Users/itsuki/Adaptive-Testing-Based-on-Reinforcement-Learning-Considering-Response-History/EXP031/results/loss_history_uncor_1_DQN_MLE_error_reduction_reward_gamma_0.3.csv
# step 1, bias 0.129, rmse 1.476, mae 1.233, cum_reward 0.157, cum_task_reward -1.107
# step 2, bias 0.203, rmse 1.335, mae 1.079, cum_reward 0.325, cum_task_reward -0.711
# step 3, bias -0.004, rmse 1.448, mae 1.110, cum_reward 0.511, cum_task_reward -1.024
# step 4, bias 0.054, rmse 1.145, mae 0.890, cum_reward 0.672, cum_task_reward -0.239
# step 5, bias 0.081, rmse 1.036, mae 0.811, cum_reward 0.837, cum_task_reward -0.001
# step 6, bias 0.032, rmse 1.004, mae 0.774, cum_reward 1.002, cum_task_reward 0.065
# step 7, bias 0.026, rmse 0.963, mae 0.738, cum_reward 1.154, cum_task_reward 0.145
# step 8, bias 0.020, rmse 0.924, mae 0.710, cum_reward 1.301, cum_task_reward 0.219
# step 9, bias 0.028, rmse 0.868, mae 0.675, cum_reward 1.447, cum_task_reward 0.319
# step 10, bias 0.030, rmse 0.839, mae 0.651, cum_reward 1.597, cum_task_reward 0.368
# step 11, bias 0.026, rmse 0.805, mae 0.622, cum_reward 1.753, cum_task_reward 0.425
# step 12, bias 0.022, rmse 0.769, mae 0.594, cum_reward 1.904, cum_task_reward 0.481
# step 13, bias 0.021, rmse 0.739, mae 0.574, cum_reward 2.050, cum_task_reward 0.526
# step 14, bias 0.023, rmse 0.719, mae 0.557, cum_reward 2.195, cum_task_reward 0.556
# step 15, bias 0.021, rmse 0.699, mae 0.542, cum_reward 2.337, cum_task_reward 0.583
# step 16, bias 0.020, rmse 0.678, mae 0.523, cum_reward 2.478, cum_task_reward 0.612
# step 17, bias 0.017, rmse 0.662, mae 0.510, cum_reward 2.615, cum_task_reward 0.634
# step 18, bias 0.014, rmse 0.649, mae 0.502, cum_reward 2.752, cum_task_reward 0.651
# step 19, bias 0.014, rmse 0.635, mae 0.492, cum_reward 2.888, cum_task_reward 0.669
# step 20, bias 0.016, rmse 0.620, mae 0.481, cum_reward 3.022, cum_task_reward 0.688
# step 21, bias 0.014, rmse 0.612, mae 0.475, cum_reward 3.153, cum_task_reward 0.698
# step 22, bias 0.015, rmse 0.599, mae 0.465, cum_reward 3.285, cum_task_reward 0.713
# step 23, bias 0.014, rmse 0.589, mae 0.455, cum_reward 3.418, cum_task_reward 0.725
# step 24, bias 0.013, rmse 0.578, mae 0.446, cum_reward 3.548, cum_task_reward 0.738
# step 25, bias 0.015, rmse 0.568, mae 0.438, cum_reward 3.679, cum_task_reward 0.750
# step 26, bias 0.018, rmse 0.558, mae 0.430, cum_reward 3.809, cum_task_reward 0.761
# step 27, bias 0.018, rmse 0.548, mae 0.423, cum_reward 3.942, cum_task_reward 0.772
# step 28, bias 0.016, rmse 0.540, mae 0.416, cum_reward 4.074, cum_task_reward 0.780
# step 29, bias 0.016, rmse 0.529, mae 0.409, cum_reward 4.203, cum_task_reward 0.793
# step 30, bias 0.014, rmse 0.520, mae 0.404, cum_reward 4.334, cum_task_reward 0.802
# step 31, bias 0.013, rmse 0.515, mae 0.399, cum_reward 4.462, cum_task_reward 0.807
# step 32, bias 0.013, rmse 0.507, mae 0.394, cum_reward 4.590, cum_task_reward 0.815
# step 33, bias 0.012, rmse 0.500, mae 0.388, cum_reward 4.719, cum_task_reward 0.822
# step 34, bias 0.012, rmse 0.492, mae 0.381, cum_reward 4.848, cum_task_reward 0.831
# step 35, bias 0.013, rmse 0.482, mae 0.374, cum_reward 4.977, cum_task_reward 0.840
# step 36, bias 0.012, rmse 0.478, mae 0.371, cum_reward 5.103, cum_task_reward 0.844
# step 37, bias 0.011, rmse 0.473, mae 0.366, cum_reward 5.234, cum_task_reward 0.849
# step 38, bias 0.009, rmse 0.468, mae 0.362, cum_reward 5.362, cum_task_reward 0.853
# step 39, bias 0.009, rmse 0.459, mae 0.356, cum_reward 5.493, cum_task_reward 0.861
# step 40, bias 0.010, rmse 0.455, mae 0.352, cum_reward 5.621, cum_task_reward 0.866
#
# Saved records to: /Users/itsuki/Adaptive-Testing-Based-on-Reinforcement-Learning-Considering-Response-History/EXP031/results/records_uncor_1_DQN_MLE_error_reduction_reward_gamma_0.3.csv
# Saved summary to: /Users/itsuki/Adaptive-Testing-Based-on-Reinforcement-Learning-Considering-Response-History/EXP031/results/summary_uncor_1_DQN_MLE_error_reduction_reward_gamma_0.3.csv
